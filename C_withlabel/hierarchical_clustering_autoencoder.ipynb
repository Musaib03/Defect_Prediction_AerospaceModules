# %% [markdown]
# # Hierarchical Clustering with Autoencoder Dimensionality Reduction
#
# This notebook performs hierarchical clustering on preprocessed data, using an autoencoder for dimensionality reduction.

# %% [markdown]
# ## Load Preprocessed Data
#
# Load the preprocessed data from 'preprocessed_data.csv' using pandas.

# %%
import pandas as pd

# Load the preprocessed data
data = pd.read_csv('cm1_preprocessed.csv')

print("Data shape:", data.shape)
data.head()
# Out:
# Data shape: (498, 22)
#         loc      v(g)     ev(g)     iv(g)         n         v         l  \
# 0  0.000237  0.004211  0.013793  0.006452  0.000145  0.000076  1.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000058  0.769231
# 2  0.054502  0.042105  0.000000  0.032258  0.029894  0.018052  0.084615
# 3  0.045024  0.031579  0.103448  0.016129  0.022179  0.012584  0.046154
# 4  0.054502  0.052632  0.172414  0.016129  0.034233  0.020213  0.046154
#
#           d         i             e  ...  lOCode  lOComment   lOBlank  \
# 0  0.010336  0.004427  6.036150e-07  ...  0.0250    0.00590  0.012195
# 1  0.007951  0.003405  4.643192e-07  ...  0.0125    0.00295  0.006098
# 2  0.075535  0.110801  1.363599e-03  ...  0.0125    0.00000  0.036585
# 3  0.127216  0.045866  1.600922e-03  ...  0.0000    0.00000  0.018293
# 4  0.137791  0.067999  2.785720e-03  ...  0.0000    0.00000  0.018293
#
#    locCodeAndComment   uniq_Op  uniq_Opnd  total_Op  total_Opnd  branchCount  \
# 0                1.0  0.002817   0.003822  0.000159    0.001474     0.002484
# 1                0.5  0.000000   0.003185  0.000000    0.001229     0.000000
# 2                0.0  0.197183   0.047771  0.034127    0.023342     0.049689
# 3                0.0  0.211268   0.025478  0.023810    0.019656     0.037267
# 4                0.0  0.211268   0.038217  0.035714    0.031941     0.062112
#
#    defects
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Perform Dimensionality Reduction with Autoencoders
#
# Build and train an autoencoder using TensorFlow/Keras to reduce the dimensionality of the data.

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data.values)

# Define autoencoder architecture
input_dim = X_scaled.shape[1]
encoding_dim = 10  # You can adjust this value

input_layer = Input(shape=(input_dim,))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(input_dim, activation='linear')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
encoder = Model(inputs=input_layer, outputs=encoded)

autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# Train the autoencoder
history = autoencoder.fit(X_scaled, X_scaled,
                          epochs=50,
                          batch_size=32,
                          shuffle=True,
                          validation_split=0.1,
                          verbose=1)

# Get the reduced-dimensional representation
X_reduced = encoder.predict(X_scaled)
print("Reduced data shape:", X_reduced.shape)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6953 - val_loss: 1.7418
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6953 - val_loss: 1.7418
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5242 - val_loss: 1.2328
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5242 - val_loss: 1.2328
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3594 - val_loss: 0.9820
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3594 - val_loss: 0.9820
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2726 - val_loss: 0.9099
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2726 - val_loss: 0.9099
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2401 - val_loss: 0.8912
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2401 - val_loss: 0.8912
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2203 - val_loss: 0.8841
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2203 - val_loss: 0.8841
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2078 - val_loss: 0.9114
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2078 - val_loss: 0.9114
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1964 - val_loss: 0.9028
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1964 - val_loss: 0.9028
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1912 - val_loss: 0.9118
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1912 - val_loss: 0.9118
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1730 - val_loss: 0.9118
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1730 - val_loss: 0.9118
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1597 - val_loss: 0.8949
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1597 - val_loss: 0.8949
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1412 - val_loss: 0.8843
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1412 - val_loss: 0.8843
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1243 - val_loss: 0.8717
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1243 - val_loss: 0.8717
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1147 - val_loss: 0.8583
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1147 - val_loss: 0.8583
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1033 - val_loss: 0.8510
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1033 - val_loss: 0.8510
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0978 - val_loss: 0.8356
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0978 - val_loss: 0.8356
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0923 - val_loss: 0.8343
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0923 - val_loss: 0.8343
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0850 - val_loss: 0.8114
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0850 - val_loss: 0.8114
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0788 - val_loss: 0.8169
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0788 - val_loss: 0.8169
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0741 - val_loss: 0.8021
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0741 - val_loss: 0.8021
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0712 - val_loss: 0.8021
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0712 - val_loss: 0.8021
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0680 - val_loss: 0.7943
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0680 - val_loss: 0.7943
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0655 - val_loss: 0.7952
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0655 - val_loss: 0.7952
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636 - val_loss: 0.7870
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636 - val_loss: 0.7870
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0617 - val_loss: 0.7872
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0617 - val_loss: 0.7872
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0590 - val_loss: 0.7859
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0590 - val_loss: 0.7859
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0573 - val_loss: 0.7909
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0573 - val_loss: 0.7909
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0560 - val_loss: 0.7955
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0560 - val_loss: 0.7955
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0538 - val_loss: 0.7945
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0538 - val_loss: 0.7945
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0518 - val_loss: 0.7716
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0518 - val_loss: 0.7716
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0509 - val_loss: 0.7649
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0509 - val_loss: 0.7649
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0495 - val_loss: 0.7377
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0495 - val_loss: 0.7377
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0478 - val_loss: 0.7543
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0478 - val_loss: 0.7543
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0458 - val_loss: 0.7506
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0458 - val_loss: 0.7506
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - val_loss: 0.7682
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - val_loss: 0.7682
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - val_loss: 0.7551
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - val_loss: 0.7551
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - val_loss: 0.7583
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - val_loss: 0.7583
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0433 - val_loss: 0.7553
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0433 - val_loss: 0.7553
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0407 - val_loss: 0.7785
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0407 - val_loss: 0.7785
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - val_loss: 0.7739
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - val_loss: 0.7739
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0398 - val_loss: 0.7887
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0398 - val_loss: 0.7887
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0421 - val_loss: 0.7682
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0421 - val_loss: 0.7682
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0381 - val_loss: 0.7190
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0381 - val_loss: 0.7190
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412 - val_loss: 0.7321
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412 - val_loss: 0.7321
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0375 - val_loss: 0.7839
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0375 - val_loss: 0.7839
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.7445
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - val_loss: 0.7445
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0382 - val_loss: 0.7128
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0382 - val_loss: 0.7128
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0332 - val_loss: 0.7427
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0332 - val_loss: 0.7427
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0309 - val_loss: 0.7268
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0309 - val_loss: 0.7268
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0294 - val_loss: 0.7135
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0294 - val_loss: 0.7135
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Reduced data shape: (498, 10)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Reduced data shape: (498, 10)

# %% [markdown]
# ## Apply Hierarchical Clustering
#
# Use the reduced-dimensional data to perform hierarchical clustering using scipy's linkage and fcluster methods.

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

# Perform hierarchical clustering
Z = linkage(X_reduced, method='ward')

# Assign cluster labels
max_clusters = 4  # You can adjust this value
cluster_labels = fcluster(Z, max_clusters, criterion='maxclust')

print("Cluster labels:", np.unique(cluster_labels))
# Out:
# Cluster labels: [1 2 3 4]

# %% [markdown]
# ## Visualize Clustering Results
#
# Visualize the clustering results using a dendrogram and scatter plots of the reduced data.

# %%
import matplotlib.pyplot as plt

# Plot dendrogram
plt.figure(figsize=(12, 6))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %%
# Scatter plot of reduced data colored by cluster labels
plt.figure(figsize=(8, 6))
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=cluster_labels, cmap='tab10', s=40)
plt.title('Clusters in Reduced-Dimensional Space')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.colorbar(label='Cluster Label')
plt.show()

# %% [markdown]
# ## Extract and Display Important Features
#
# Extract and display the most important features based on encoder input weights.

# %%
import numpy as np
feature_names = data.columns.tolist()
# Get weights from input to first encoder layer
weights = encoder.layers[1].get_weights()[0]  # shape: (input_dim, 64)
importance = np.sum(np.abs(weights), axis=1)
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
print("Top important features from autoencoder:")
display(importance_df.head(10))
# Out:
# Top important features from autoencoder:
#               Feature  Importance
# 16            uniq_Op   10.171955
# 6                   l    9.936831
# 11                  t    9.918232
# 8                   i    9.882616
# 21            defects    9.704212
# 15  locCodeAndComment    9.604183
# 13          lOComment    9.481806
# 1                v(g)    9.444275
# 7                   d    9.215008
# 18           total_Op    9.184295

# %% [markdown]
# ## Handle Class Imbalance with SMOTEENN
#
# Apply SMOTEENN to balance the classes in the dataset.

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (from imblearn) (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (2.3.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.16.1)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: joblib<2,>=1.2.0 in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /home/musaib/Projects/Software_Defect_Prediction_aerospace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (3.6.0)

# %%
from imblearn.combine import SMOTEENN

# Separate features and target
X = data.drop('defects', axis=1)
y = data['defects']

# Apply SMOTEENN
smote_enn = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote_enn.fit_resample(X, y)

# Combine resampled features and target into a DataFrame
resampled_data = X_resampled.copy()
resampled_data['defects'] = y_resampled

# Save to CSV
resampled_data.to_csv('smoteenn_resampled_data.csv', index=False)

print('Original class distribution:')
print(y.value_counts())
print('Resampled class distribution:')
print(pd.Series(y_resampled).value_counts())
print('Resampled data saved to smoteenn_resampled_data.csv')
# Out:
# Original class distribution:
# defects
# False    449
# True      49
# Name: count, dtype: int64
# Resampled class distribution:
# defects
# True     426
# False    297
# Name: count, dtype: int64
# Resampled data saved to smoteenn_resampled_data.csv
